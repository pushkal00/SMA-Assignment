# %%
import networkx as nx
from networkx.algorithms.community.modularity_max import greedy_modularity_communities
import matplotlib.pyplot as plt
import time

# %%
def modularity_clustering(G):
    def plot_clusters(clusters):
        val_map = {}
        idx = 0
        for cluster in clusters:
            for node in cluster:
                val_map[node] = idx
            idx += 1
        values = [val_map.get(node) for node in G.nodes()]
        nx.draw(G, cmap=plt.get_cmap('viridis'), node_color=values, with_labels=True, font_color='white')
        plt.show()

    old = time.time()
    communities = tuple(greedy_modularity_communities(G))
    new = time.time()
    print("running time:", new-old)
    print("num clusters:", len(communities))
    print("Modularity: " + str(nx.algorithms.community.modularity(G, communities)))
    plot_clusters(communities)
    return communities

# %%
dolphins_graph = nx.read_gml("dolphins.gml")
clusters = modularity_clustering(dolphins_graph)
for cluster in clusters:
    print(cluster)
# Out:
# running time: 0.006094455718994141
# num clusters: 4
# Modularity: 0.4954906847039278
# frozenset({'Zipfel', 'TR77', 'Whitetip', 'SN9', 'Thumper', 'Scabs', 'SN63', 'SN96', 'Beak', 'Bumper', 'Shmuddel', 'TR88', 'TR120', 'Stripes', 'TSN83', 'Fork', 'TR99', 'Kringel', 'SN4', 'Fish', 'Hook', 'TSN103', 'Grin'})
# frozenset({'PL', 'MN23', 'SN90', 'Wave', 'Jet', 'Quasi', 'Feather', 'Notch', 'Gallatin', 'Oscar', 'Number1', 'Ripplefluke', 'Web', 'Mus', 'Zig', 'Upbang', 'Beescratch', 'DN63', 'TR82', 'DN16', 'DN21', 'Knit'})
# frozenset({'Five', 'Vau', 'Zap', 'Double', 'MN105', 'Topless', 'CCL', 'MN83', 'MN60', 'SMN5', 'Trigger', 'Jonah', 'Cross', 'Patchback', 'Haecksel'})
# frozenset({'SN100', 'SN89'})

# %%
karate_graph = nx.read_gml("karate.gml", label="id")
clusters = modularity_clustering(karate_graph)
for cluster in clusters:
    print(cluster)
# Out:
# running time: 0.0041921138763427734
# num clusters: 3
# Modularity: 0.3806706114398422
# frozenset({32, 33, 34, 9, 15, 16, 19, 21, 23, 24, 25, 26, 27, 28, 29, 30, 31})
# frozenset({2, 3, 4, 8, 10, 13, 14, 18, 22})
# frozenset({1, 5, 6, 7, 11, 12, 17, 20})

# %%
jazz_graph = nx.read_gml("jazz.gml")
clusters = modularity_clustering(jazz_graph)
for cluster in clusters:
    print(cluster)
# Out:
# running time: 0.0819091796875
# num clusters: 4
# Modularity: 0.43890781537538287
# frozenset({'63', '66', '9', '154', '58', '50', '17', '32', '95', '103', '104', '107', '188', '116', '1', '44', '35', '62', '81', '100', '48', '162', '132', '170', '65', '99', '134', '120', '139', '91', '166', '123', '98', '187', '8', '24', '110', '159', '74', '135', '182', '179', '38', '131', '119', '22', '108', '46', '105', '43', '122', '40', '33', '42', '78', '80', '171', '16', '15', '109', '106', '101', '168', '60', '68', '64', '23'})
# frozenset({'14', '151', '10', '117', '71', '57', '193', '125', '111', '141', '190', '146', '158', '192', '72', '161', '53', '20', '34', '67', '36', '83', '137', '183', '118', '185', '93', '114', '113', '127', '94', '197', '177', '56', '70', '150', '164', '54', '52', '142', '112', '175', '87', '12', '11', '2', '19', '130', '186', '55', '49', '194', '30', '7', '165', '69', '31', '195', '121', '178', '89', '61', '196', '174', '84', '129'})
# frozenset({'180', '85', '148', '3', '163', '51', '79', '160', '149', '176', '169', '6', '140', '152', '29', '96', '124', '86', '41', '155', '115', '184', '167', '90', '102', '172', '126', '128', '133', '25', '88', '77', '45', '39', '75', '76', '145', '153', '181', '26', '21', '27', '4', '18', '97', '198', '157', '13', '73', '92', '189', '173', '147', '144', '28', '138', '156', '136', '37', '5', '47', '191'})
# frozenset({'82', '59', '143'})
